# %%
import os
import subprocess


dataType = 'exvivo' #or 'exvivo
baseDir = '/Users/dennis.jungchildmind.org/Library/CloudStorage/OneDrive-ChildMindInstitute/hcp1200-thickness' if dataType == 'hcp' else '/Users/dennis.jungchildmind.org/Downloads/exvivo/'

boundary = '' if dataType == 'exvivo' else ''
#inf.pial. ; wm.inf. ;  or ''
subject_dirs = [d for d in os.listdir(baseDir) if os.path.isdir(os.path.join(baseDir, d))]

radii = [6]
for radius in radii:
    #wb_command -metric-smoothing lh.inf.32k_fs_LR.surf.gii lh.thickness.32k_fs_LR.shape.gii 10 lh.thickness.32k_10mm_fwhm_fs_LR.shape.gii -fwhm
      #      wm2inf_thickness = nib.load(f'{baseDir}{subjectDir}/lh.thickness.wm.inf.32k_fs_LR.shape.gii')
      #  inf2pial_thickness = nib.load(f'{baseDir}{subjectDir}/lh.thickness.inf.pial.32k_fs_LR.shape.gii')
    
    for subject in subject_dirs:
        print(f'{subject} {radius}')

        if dataType == 'exvivo':
          if os.path.exists(f'{baseDir}/{subject}/lh.inf.32k_fs_LR.surf.gii'):
              #surface_path = f'{baseDir}/{subject}/lh.inf.32k_fs_LR.surf.gii'
              surface_path = '/Users/dennis.jungchildmind.org/Downloads/HCP_S1200_Atlas_Z4_pkXDZ/S1200.L.midthickness_MSMAll.32k_fs_LR.surf.gii'
              shape_in_path = f'{baseDir}/{subject}/lh.thickness.{boundary}32k_fs_LR.shape.gii'
              shape_out_path = f'{baseDir}/{subject}/lh.thickness.{boundary}32k_{radius}mm_fwhm_fs_LR.shape.gii'
              print(f'{surface_path} {shape_in_path} {shape_out_path}')
              subprocess.run(f"""
                              wb_command -metric-smoothing '{surface_path}' '{shape_in_path}' {radius} '{shape_out_path}' -fwhm -fix-zeros
                              """,shell=True)

          if os.path.exists(f'{baseDir}/{subject}/rh.inf.32k_fs_LR.surf.gii'):
              surface_path = f'{baseDir}/{subject}/rh.inf.32k_fs_LR.surf.gii'
              surface_path = '/Users/dennis.jungchildmind.org/Downloads/HCP_S1200_Atlas_Z4_pkXDZ/S1200.R.midthickness_MSMAll.32k_fs_LR.surf.gii'
              shape_in_path = f'{baseDir}/{subject}/rh.thickness.{boundary}32k_fs_LR.shape.gii'
              shape_out_path = f'{baseDir}/{subject}/rh.thickness.{boundary}32k_{radius}mm_fwhm_fs_LR.shape.gii'
              print(f'{surface_path} {shape_in_path} {shape_out_path}')
              subprocess.run(f"""
                              wb_command -metric-smoothing '{surface_path}' '{shape_in_path}' {radius} '{shape_out_path}' -fwhm -fix-zeros
                              """,shell=True)
              
        elif dataType == 'hcp':
          if os.path.exists(f'{baseDir}/{subject}/{subject}.L.thickness.32k_fs_LR.shape.gii'):
              #surface_path = f'{baseDir}/{subject}/lh.inf.32k_fs_LR.surf.gii'
              surface_path = '/Users/dennis.jungchildmind.org/Downloads/HCP_S1200_Atlas_Z4_pkXDZ/S1200.L.midthickness_MSMAll.32k_fs_LR.surf.gii'
              shape_in_path = f'{baseDir}/{subject}/{subject}.L.thickness.32k_fs_LR.shape.gii'
              shape_out_path = f'{baseDir}/{subject}/{subject}.L.thickness.32k_{radius}mm_fwhm_fs_LR.shape.gii'
              print(f'{surface_path} {shape_in_path} {shape_out_path}')
              subprocess.run(f"""
                              wb_command -metric-smoothing '{surface_path}' '{shape_in_path}' {radius} '{shape_out_path}' -fwhm -fix-zeros
                              """,shell=True)

          if os.path.exists(f'{baseDir}/{subject}/{subject}.R.thickness.32k_fs_LR.shape.gii'):
              surface_path = f'{baseDir}/{subject}/rh.inf.32k_fs_LR.surf.gii'
              #surface_path = '/Users/dennis.jungchildmind.org/Downloads/HCP_S1200_Atlas_Z4_pkXDZ/S1200.R.midthickness_MSMAll.32k_fs_LR.surf.gii'
              shape_in_path = f'{baseDir}/{subject}/{subject}.R.thickness.32k_fs_LR.shape.gii'
              shape_out_path = f'{baseDir}/{subject}/{subject}.R.thickness.32k_{radius}mm_fwhm_fs_LR.shape.gii'
              print(f'{surface_path} {shape_in_path} {shape_out_path}')
              subprocess.run(f"""
                              wb_command -metric-smoothing '{surface_path}' '{shape_in_path}' {radius} '{shape_out_path}' -fwhm -fix-zeros
                              """,shell=True)
# Out:
# I57_new_confidence 6
# /Users/dennis.jungchildmind.org/Downloads/HCP_S1200_Atlas_Z4_pkXDZ/S1200.L.midthickness_MSMAll.32k_fs_LR.surf.gii /Users/dennis.jungchildmind.org/Downloads/exvivo//I57_new_confidence/lh.thickness.32k_fs_LR.shape.gii /Users/dennis.jungchildmind.org/Downloads/exvivo//I57_new_confidence/lh.thickness.32k_6mm_fwhm_fs_LR.shape.gii
# I58_new_confidence 6
# /Users/dennis.jungchildmind.org/Downloads/HCP_S1200_Atlas_Z4_pkXDZ/S1200.L.midthickness_MSMAll.32k_fs_LR.surf.gii /Users/dennis.jungchildmind.org/Downloads/exvivo//I58_new_confidence/lh.thickness.32k_fs_LR.shape.gii /Users/dennis.jungchildmind.org/Downloads/exvivo//I58_new_confidence/lh.thickness.32k_6mm_fwhm_fs_LR.shape.gii
# I45_new_confidence 6
# /Users/dennis.jungchildmind.org/Downloads/HCP_S1200_Atlas_Z4_pkXDZ/S1200.L.midthickness_MSMAll.32k_fs_LR.surf.gii /Users/dennis.jungchildmind.org/Downloads/exvivo//I45_new_confidence/lh.thickness.32k_fs_LR.shape.gii /Users/dennis.jungchildmind.org/Downloads/exvivo//I45_new_confidence/lh.thickness.32k_6mm_fwhm_fs_LR.shape.gii
# I59_new_confidence 6
# /Users/dennis.jungchildmind.org/Downloads/HCP_S1200_Atlas_Z4_pkXDZ/S1200.R.midthickness_MSMAll.32k_fs_LR.surf.gii /Users/dennis.jungchildmind.org/Downloads/exvivo//I59_new_confidence/rh.thickness.32k_fs_LR.shape.gii /Users/dennis.jungchildmind.org/Downloads/exvivo//I59_new_confidence/rh.thickness.32k_6mm_fwhm_fs_LR.shape.gii
# I56_new_confidence 6
# /Users/dennis.jungchildmind.org/Downloads/HCP_S1200_Atlas_Z4_pkXDZ/S1200.R.midthickness_MSMAll.32k_fs_LR.surf.gii /Users/dennis.jungchildmind.org/Downloads/exvivo//I56_new_confidence/rh.thickness.32k_fs_LR.shape.gii /Users/dennis.jungchildmind.org/Downloads/exvivo//I56_new_confidence/rh.thickness.32k_6mm_fwhm_fs_LR.shape.gii
# I41_new_confidence 6
# /Users/dennis.jungchildmind.org/Downloads/HCP_S1200_Atlas_Z4_pkXDZ/S1200.L.midthickness_MSMAll.32k_fs_LR.surf.gii /Users/dennis.jungchildmind.org/Downloads/exvivo//I41_new_confidence/lh.thickness.32k_fs_LR.shape.gii /Users/dennis.jungchildmind.org/Downloads/exvivo//I41_new_confidence/lh.thickness.32k_6mm_fwhm_fs_LR.shape.gii
# I54_new_confidence 6
# /Users/dennis.jungchildmind.org/Downloads/HCP_S1200_Atlas_Z4_pkXDZ/S1200.L.midthickness_MSMAll.32k_fs_LR.surf.gii /Users/dennis.jungchildmind.org/Downloads/exvivo//I54_new_confidence/lh.thickness.32k_fs_LR.shape.gii /Users/dennis.jungchildmind.org/Downloads/exvivo//I54_new_confidence/lh.thickness.32k_6mm_fwhm_fs_LR.shape.gii
# /Users/dennis.jungchildmind.org/Downloads/HCP_S1200_Atlas_Z4_pkXDZ/S1200.R.midthickness_MSMAll.32k_fs_LR.surf.gii /Users/dennis.jungchildmind.org/Downloads/exvivo//I54_new_confidence/rh.thickness.32k_fs_LR.shape.gii /Users/dennis.jungchildmind.org/Downloads/exvivo//I54_new_confidence/rh.thickness.32k_6mm_fwhm_fs_LR.shape.gii
# I38_new_confidence 6
# /Users/dennis.jungchildmind.org/Downloads/HCP_S1200_Atlas_Z4_pkXDZ/S1200.L.midthickness_MSMAll.32k_fs_LR.surf.gii /Users/dennis.jungchildmind.org/Downloads/exvivo//I38_new_confidence/lh.thickness.32k_fs_LR.shape.gii /Users/dennis.jungchildmind.org/Downloads/exvivo//I38_new_confidence/lh.thickness.32k_6mm_fwhm_fs_LR.shape.gii
# I53_new_confidence 6
# /Users/dennis.jungchildmind.org/Downloads/HCP_S1200_Atlas_Z4_pkXDZ/S1200.L.midthickness_MSMAll.32k_fs_LR.surf.gii /Users/dennis.jungchildmind.org/Downloads/exvivo//I53_new_confidence/lh.thickness.32k_fs_LR.shape.gii /Users/dennis.jungchildmind.org/Downloads/exvivo//I53_new_confidence/lh.thickness.32k_6mm_fwhm_fs_LR.shape.gii
# I46_new_confidence 6
# /Users/dennis.jungchildmind.org/Downloads/HCP_S1200_Atlas_Z4_pkXDZ/S1200.L.midthickness_MSMAll.32k_fs_LR.surf.gii /Users/dennis.jungchildmind.org/Downloads/exvivo//I46_new_confidence/lh.thickness.32k_fs_LR.shape.gii /Users/dennis.jungchildmind.org/Downloads/exvivo//I46_new_confidence/lh.thickness.32k_6mm_fwhm_fs_LR.shape.gii
# EXC022_new_confidence 6
# /Users/dennis.jungchildmind.org/Downloads/HCP_S1200_Atlas_Z4_pkXDZ/S1200.L.midthickness_MSMAll.32k_fs_LR.surf.gii /Users/dennis.jungchildmind.org/Downloads/exvivo//EXC022_new_confidence/lh.thickness.32k_fs_LR.shape.gii /Users/dennis.jungchildmind.org/Downloads/exvivo//EXC022_new_confidence/lh.thickness.32k_6mm_fwhm_fs_LR.shape.gii
# I52_new_confidence 6
# /Users/dennis.jungchildmind.org/Downloads/HCP_S1200_Atlas_Z4_pkXDZ/S1200.R.midthickness_MSMAll.32k_fs_LR.surf.gii /Users/dennis.jungchildmind.org/Downloads/exvivo//I52_new_confidence/rh.thickness.32k_fs_LR.shape.gii /Users/dennis.jungchildmind.org/Downloads/exvivo//I52_new_confidence/rh.thickness.32k_6mm_fwhm_fs_LR.shape.gii
# I48_new_confidence 6
# /Users/dennis.jungchildmind.org/Downloads/HCP_S1200_Atlas_Z4_pkXDZ/S1200.L.midthickness_MSMAll.32k_fs_LR.surf.gii /Users/dennis.jungchildmind.org/Downloads/exvivo//I48_new_confidence/lh.thickness.32k_fs_LR.shape.gii /Users/dennis.jungchildmind.org/Downloads/exvivo//I48_new_confidence/lh.thickness.32k_6mm_fwhm_fs_LR.shape.gii
# I55_new_confidence 6
# /Users/dennis.jungchildmind.org/Downloads/HCP_S1200_Atlas_Z4_pkXDZ/S1200.L.midthickness_MSMAll.32k_fs_LR.surf.gii /Users/dennis.jungchildmind.org/Downloads/exvivo//I55_new_confidence/lh.thickness.32k_fs_LR.shape.gii /Users/dennis.jungchildmind.org/Downloads/exvivo//I55_new_confidence/lh.thickness.32k_6mm_fwhm_fs_LR.shape.gii
# I61_new_confidence 6
# /Users/dennis.jungchildmind.org/Downloads/HCP_S1200_Atlas_Z4_pkXDZ/S1200.R.midthickness_MSMAll.32k_fs_LR.surf.gii /Users/dennis.jungchildmind.org/Downloads/exvivo//I61_new_confidence/rh.thickness.32k_fs_LR.shape.gii /Users/dennis.jungchildmind.org/Downloads/exvivo//I61_new_confidence/rh.thickness.32k_6mm_fwhm_fs_LR.shape.gii
# KC001_new_confidence 6
# /Users/dennis.jungchildmind.org/Downloads/HCP_S1200_Atlas_Z4_pkXDZ/S1200.R.midthickness_MSMAll.32k_fs_LR.surf.gii /Users/dennis.jungchildmind.org/Downloads/exvivo//KC001_new_confidence/rh.thickness.32k_fs_LR.shape.gii /Users/dennis.jungchildmind.org/Downloads/exvivo//KC001_new_confidence/rh.thickness.32k_6mm_fwhm_fs_LR.shape.gii
# I60_new_confidence 6
# /Users/dennis.jungchildmind.org/Downloads/HCP_S1200_Atlas_Z4_pkXDZ/S1200.R.midthickness_MSMAll.32k_fs_LR.surf.gii /Users/dennis.jungchildmind.org/Downloads/exvivo//I60_new_confidence/rh.thickness.32k_fs_LR.shape.gii /Users/dennis.jungchildmind.org/Downloads/exvivo//I60_new_confidence/rh.thickness.32k_6mm_fwhm_fs_LR.shape.gii

# %%
#the second code for bigbrain data
import os
import subprocess

baseDir = '/Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample'
#find all the surf.gii files in the baseDir
shape_files = [f for f in os.listdir(baseDir) if f.endswith('.shape.gii')]

radii = [6]
for radius in radii:
    for shape_file in shape_files:
        #if the shape_file first characters match lh. 
        if shape_file.startswith('lh.'):
            print(f'{shape_file} {radius}')
            shape_in_path = f'{baseDir}/{shape_file}'
            shape_out_path = f'{baseDir}/{shape_file[:-9]}_{radius}mm_fwhm.shape.gii'
            surface_path = '/Users/dennis.jungchildmind.org/Downloads/HCP_S1200_Atlas_Z4_pkXDZ/S1200.L.midthickness_MSMAll.32k_fs_LR.surf.gii'
            print(f'{shape_in_path} {shape_out_path}')
        elif shape_file.startswith('rh.'):
            print(f'{shape_file} {radius}')
            shape_in_path = f'{baseDir}/{shape_file}'
            shape_out_path = f'{baseDir}/{shape_file[:-9]}_{radius}mm_fwhm.shape.gii'
            surface_path = '/Users/dennis.jungchildmind.org/Downloads/HCP_S1200_Atlas_Z4_pkXDZ/S1200.R.midthickness_MSMAll.32k_fs_LR.surf.gii'
            print(f'{shape_in_path} {shape_out_path}')
        else:
            #throw error
            raise ValueError(f'Shape file {shape_file} does not start with lh. or rh.')
        subprocess.run(f"""
                        wb_command -metric-smoothing '{surface_path}' '{shape_in_path}' {radius} '{shape_out_path}' -fwhm -fix-zeros
                        """,shell=True)


              
#wb_command -metric-smoothing '{surface_path}' '{shape_in_path}' {radius} '{shape_out_path}' -fwhm -fix-zeros
# Out:
# lh.0-4.32k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-4.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-4.32k_6mm_fwhm.shape.gii
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-4.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-4.32k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-4.32k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: lh.0-4.32k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.3-4.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.3-4.164k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.3-4.164k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: rh.3-4.164k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.3-4.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.3-4.32k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.3-4.32k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: rh.3-4.32k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.1-2.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.1-2.32k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.1-2.32k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: rh.1-2.32k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.3-6.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.3-6.164k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.3-6.164k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: lh.3-6.164k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
# rh.3-4.164k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.3-4.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.3-4.164k_6mm_fwhm.shape.gii
# rh.3-4.32k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.3-4.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.3-4.32k_6mm_fwhm.shape.gii
# rh.1-2.32k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.1-2.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.1-2.32k_6mm_fwhm.shape.gii
# lh.3-6.164k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.3-6.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.3-6.164k_6mm_fwhm.shape.gii
# lh.2-6.32k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.2-6.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.2-6.32k_6mm_fwhm.shape.gii
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.2-6.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.2-6.32k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.2-6.32k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: lh.2-6.32k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.5-6.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.5-6.32k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.5-6.32k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: lh.5-6.32k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.2-3.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.2-3.164k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.2-3.164k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: lh.2-3.164k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-3.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-3.32k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-3.32k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: lh.0-3.32k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
# lh.5-6.32k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.5-6.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.5-6.32k_6mm_fwhm.shape.gii
# lh.2-3.164k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.2-3.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.2-3.164k_6mm_fwhm.shape.gii
# lh.0-3.32k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-3.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-3.32k_6mm_fwhm.shape.gii
# rh.2-6.164k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.2-6.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.2-6.164k_6mm_fwhm.shape.gii
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.2-6.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.2-6.164k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.2-6.164k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: rh.2-6.164k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-1.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-1.32k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-1.32k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: rh.0-1.32k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.4-6.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.4-6.32k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.4-6.32k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: lh.4-6.32k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.2-3.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.2-3.32k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.2-3.32k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: rh.2-3.32k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.2-6.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.2-6.164k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.2-6.164k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: lh.2-6.164k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
# rh.0-1.32k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-1.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-1.32k_6mm_fwhm.shape.gii
# lh.4-6.32k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.4-6.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.4-6.32k_6mm_fwhm.shape.gii
# rh.2-3.32k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.2-3.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.2-3.32k_6mm_fwhm.shape.gii
# lh.2-6.164k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.2-6.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.2-6.164k_6mm_fwhm.shape.gii
# rh.2-3.164k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.2-3.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.2-3.164k_6mm_fwhm.shape.gii
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.2-3.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.2-3.164k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.2-3.164k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: rh.2-3.164k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.3-4.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.3-4.164k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.3-4.164k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: lh.3-4.164k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.3-6.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.3-6.32k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.3-6.32k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: lh.3-6.32k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.3-6.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.3-6.164k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.3-6.164k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: rh.3-6.164k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
# lh.3-4.164k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.3-4.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.3-4.164k_6mm_fwhm.shape.gii
# lh.3-6.32k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.3-6.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.3-6.32k_6mm_fwhm.shape.gii
# rh.3-6.164k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.3-6.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.3-6.164k_6mm_fwhm.shape.gii
# rh.0-2.32k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-2.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-2.32k_6mm_fwhm.shape.gii
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-2.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-2.32k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-2.32k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: rh.0-2.32k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-6.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-6.32k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-6.32k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: rh.0-6.32k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.4-5.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.4-5.32k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.4-5.32k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: lh.4-5.32k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.5-6.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.5-6.32k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.5-6.32k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: rh.5-6.32k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-3.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-3.32k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-3.32k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: rh.0-3.32k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
# rh.0-6.32k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-6.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-6.32k_6mm_fwhm.shape.gii
# lh.4-5.32k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.4-5.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.4-5.32k_6mm_fwhm.shape.gii
# rh.5-6.32k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.5-6.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.5-6.32k_6mm_fwhm.shape.gii
# rh.0-3.32k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-3.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-3.32k_6mm_fwhm.shape.gii
# rh.4-6.164k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.4-6.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.4-6.164k_6mm_fwhm.shape.gii
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.4-6.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.4-6.164k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.4-6.164k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: rh.4-6.164k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-2.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-2.164k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-2.164k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: lh.0-2.164k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-4.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-4.32k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-4.32k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: rh.0-4.32k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-3.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-3.164k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-3.164k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: lh.0-3.164k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
# lh.0-2.164k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-2.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-2.164k_6mm_fwhm.shape.gii
# rh.0-4.32k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-4.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-4.32k_6mm_fwhm.shape.gii
# lh.0-3.164k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-3.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-3.164k_6mm_fwhm.shape.gii
# rh.0-6.164k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-6.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-6.164k_6mm_fwhm.shape.gii
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-6.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-6.164k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-6.164k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: rh.0-6.164k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.3-4.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.3-4.32k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.3-4.32k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: lh.3-4.32k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.1-2.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.1-2.32k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.1-2.32k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: lh.1-2.32k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-1.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-1.164k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-1.164k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: rh.0-1.164k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
# lh.3-4.32k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.3-4.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.3-4.32k_6mm_fwhm.shape.gii
# lh.1-2.32k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.1-2.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.1-2.32k_6mm_fwhm.shape.gii
# rh.0-1.164k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-1.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-1.164k_6mm_fwhm.shape.gii
# lh.5-6.164k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.5-6.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.5-6.164k_6mm_fwhm.shape.gii
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.5-6.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.5-6.164k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.5-6.164k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: lh.5-6.164k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.2-6.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.2-6.32k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.2-6.32k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: rh.2-6.32k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
# rh.2-6.32k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.2-6.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.2-6.32k_6mm_fwhm.shape.gii
# rh.1-2.164k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.1-2.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.1-2.164k_6mm_fwhm.shape.gii
# lh.4-5.164k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.4-5.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.4-5.164k_6mm_fwhm.shape.gii
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.1-2.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.1-2.164k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.1-2.164k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: rh.1-2.164k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.4-5.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.4-5.164k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.4-5.164k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: lh.4-5.164k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-4.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-4.164k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-4.164k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: lh.0-4.164k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-6.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-6.164k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-6.164k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: lh.0-6.164k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
# lh.0-4.164k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-4.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-4.164k_6mm_fwhm.shape.gii
# lh.0-6.164k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-6.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-6.164k_6mm_fwhm.shape.gii
# rh.0-3.164k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-3.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-3.164k_6mm_fwhm.shape.gii
# rh.4-5.164k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.4-5.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.4-5.164k_6mm_fwhm.shape.gii
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-3.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-3.164k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-3.164k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: rh.0-3.164k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.4-5.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.4-5.164k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.4-5.164k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: rh.4-5.164k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-4.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-4.164k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-4.164k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: rh.0-4.164k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.1-2.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.1-2.164k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.1-2.164k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: lh.1-2.164k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
# rh.0-4.164k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-4.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-4.164k_6mm_fwhm.shape.gii
# lh.1-2.164k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.1-2.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.1-2.164k_6mm_fwhm.shape.gii
# rh.3-6.32k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.3-6.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.3-6.32k_6mm_fwhm.shape.gii
# rh.5-6.164k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.5-6.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.5-6.164k_6mm_fwhm.shape.gii
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.3-6.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.3-6.32k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.3-6.32k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: rh.3-6.32k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.5-6.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.5-6.164k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.5-6.164k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: rh.5-6.164k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
# lh.0-1.164k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-1.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-1.164k_6mm_fwhm.shape.gii
# lh.0-2.32k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-2.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-2.32k_6mm_fwhm.shape.gii
# rh.4-5.32k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.4-5.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.4-5.32k_6mm_fwhm.shape.gii
# lh.0-6.32k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-6.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-6.32k_6mm_fwhm.shape.gii
# lh.0-1.32k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-1.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-1.32k_6mm_fwhm.shape.gii
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-1.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-1.164k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-1.164k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: lh.0-1.164k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-2.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-2.32k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-2.32k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: lh.0-2.32k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.4-5.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.4-5.32k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.4-5.32k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: rh.4-5.32k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-6.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-6.32k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-6.32k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: lh.0-6.32k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-1.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-1.32k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.0-1.32k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: lh.0-1.32k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
# rh.4-6.32k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.4-6.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.4-6.32k_6mm_fwhm.shape.gii
# lh.2-3.32k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.2-3.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.2-3.32k_6mm_fwhm.shape.gii
# rh.0-2.164k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-2.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-2.164k_6mm_fwhm.shape.gii
# lh.4-6.164k.shape.gii 6
# /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.4-6.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.4-6.164k_6mm_fwhm.shape.gii
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.4-6.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.4-6.32k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.4-6.32k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: rh.4-6.32k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.2-3.32k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.2-3.32k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.2-3.32k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: lh.2-3.32k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-2.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-2.164k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/rh.0-2.164k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: rh.0-2.164k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
#
#
# While running:
# /Applications/workbench/bin_macosxub/../macosxub_apps/wb_command.app/Contents/MacOS/wb_command -metric-smoothing /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.4-6.164k.shape.gii /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.4-6.164k.shape.gii 6 /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample/lh.4-6.164k_6mm_fwhm.shape.gii -fwhm -fix-zeros
#
# ERROR: NAME OF FILE: lh.4-6.164k.shape.gii
# PATH TO FILE: /Users/dennis.jungchildmind.org/Downloads/BigBrain/thickness/resample
#    Number of data arrays MUST be two in a SurfaceFile.
