# %% [markdown]
# ### Calculate distance away from the surface normals

# %%
# Import required libraries
import numpy as np
import nibabel as nib
from scipy.ndimage import map_coordinates
import os
import matplotlib.pyplot as plt
import re
from scipy.stats import zscore
from qc_util import *

# %% [markdown]
# #### run calculate surface normals and c oordinates using the qc_util.py function before executing the next part

# %%
# Example usage:
DATA_TYPE = 'exvivo2'
DATA_PATH = "/Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data/"
calculate_surfnorm_and_coords(DATA_TYPE, DATA_PATH)
# Out:
# pial.*\.32k_fs_LR\.surf\.gii
# ['lh.pial.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I64/lh.pial.32k_fs_LR.surf.gii in I64
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I64/lh.pial.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I64/lh.pial.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I64
# white.*\.32k_fs_LR\.surf\.gii
# ['lh.white.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I64/lh.white.32k_fs_LR.surf.gii in I64
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I64/lh.white.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I64/lh.white.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I64
# inf.*\.32k_fs_LR\.surf\.gii
# ['lh.inflated.32k_fs_LR.surf.gii', 'lh.inf.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I64/lh.inflated.32k_fs_LR.surf.gii in I64
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I64/lh.inflated.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I64/lh.inflated.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I64
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I64/lh.inf.32k_fs_LR.surf.gii in I64
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I64/lh.inf.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I64/lh.inf.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I64
# pial.*\.32k_fs_LR\.surf\.gii
# ['rh.pial.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I63/rh.pial.32k_fs_LR.surf.gii in I63
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I63/rh.pial.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I63/rh.pial.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I63
# white.*\.32k_fs_LR\.surf\.gii
# ['rh.white.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I63/rh.white.32k_fs_LR.surf.gii in I63
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I63/rh.white.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I63/rh.white.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I63
# inf.*\.32k_fs_LR\.surf\.gii
# ['rh.inflated.32k_fs_LR.surf.gii', 'rh.inf.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I63/rh.inflated.32k_fs_LR.surf.gii in I63
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I63/rh.inflated.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I63/rh.inflated.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I63
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I63/rh.inf.32k_fs_LR.surf.gii in I63
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I63/rh.inf.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I63/rh.inf.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I63
# pial.*\.32k_fs_LR\.surf\.gii
# ['lh.pial.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I55/lh.pial.32k_fs_LR.surf.gii in I55
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I55/lh.pial.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I55/lh.pial.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I55
# white.*\.32k_fs_LR\.surf\.gii
# ['lh.white.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I55/lh.white.32k_fs_LR.surf.gii in I55
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I55/lh.white.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I55/lh.white.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I55
# inf.*\.32k_fs_LR\.surf\.gii
# ['lh.inflated.32k_fs_LR.surf.gii', 'lh.inf.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I55/lh.inflated.32k_fs_LR.surf.gii in I55
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I55/lh.inflated.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I55/lh.inflated.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I55
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I55/lh.inf.32k_fs_LR.surf.gii in I55
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I55/lh.inf.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I55/lh.inf.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I55
# pial.*\.32k_fs_LR\.surf\.gii
# ['lh.pial.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I53/lh.pial.32k_fs_LR.surf.gii in I53
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I53/lh.pial.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I53/lh.pial.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I53
# white.*\.32k_fs_LR\.surf\.gii
# ['lh.white.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I53/lh.white.32k_fs_LR.surf.gii in I53
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I53/lh.white.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I53/lh.white.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I53
# inf.*\.32k_fs_LR\.surf\.gii
# ['lh.inflated.32k_fs_LR.surf.gii', 'lh.inf.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I53/lh.inflated.32k_fs_LR.surf.gii in I53
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I53/lh.inflated.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I53/lh.inflated.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I53
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I53/lh.inf.32k_fs_LR.surf.gii in I53
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I53/lh.inf.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I53/lh.inf.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I53
# pial.*\.32k_fs_LR\.surf\.gii
# ['lh.pial.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I62/lh.pial.32k_fs_LR.surf.gii in I62
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I62/lh.pial.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I62/lh.pial.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I62
# white.*\.32k_fs_LR\.surf\.gii
# ['lh.white.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I62/lh.white.32k_fs_LR.surf.gii in I62
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I62/lh.white.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I62/lh.white.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I62
# inf.*\.32k_fs_LR\.surf\.gii
# ['lh.inflated.32k_fs_LR.surf.gii', 'lh.inf.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I62/lh.inflated.32k_fs_LR.surf.gii in I62
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I62/lh.inflated.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I62/lh.inflated.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I62
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I62/lh.inf.32k_fs_LR.surf.gii in I62
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I62/lh.inf.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I62/lh.inf.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I62
# pial.*\.32k_fs_LR\.surf\.gii
# ['lh.pial.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I38/lh.pial.32k_fs_LR.surf.gii in I38
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I38/lh.pial.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I38/lh.pial.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I38
# white.*\.32k_fs_LR\.surf\.gii
# ['lh.white.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I38/lh.white.32k_fs_LR.surf.gii in I38
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I38/lh.white.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I38/lh.white.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I38
# inf.*\.32k_fs_LR\.surf\.gii
# ['lh.inflated.32k_fs_LR.surf.gii', 'lh.inf.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I38/lh.inflated.32k_fs_LR.surf.gii in I38
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I38/lh.inflated.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I38/lh.inflated.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I38
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I38/lh.inf.32k_fs_LR.surf.gii in I38
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I38/lh.inf.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I38/lh.inf.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I38
# pial.*\.32k_fs_LR\.surf\.gii
# ['lh.pial.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/HCPA1/lh.pial.32k_fs_LR.surf.gii in HCPA1
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/HCPA1/lh.pial.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/HCPA1/lh.pial.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for HCPA1
# white.*\.32k_fs_LR\.surf\.gii
# ['lh.white.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/HCPA1/lh.white.32k_fs_LR.surf.gii in HCPA1
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/HCPA1/lh.white.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/HCPA1/lh.white.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for HCPA1
# inf.*\.32k_fs_LR\.surf\.gii
# ['lh.inflated.32k_fs_LR.surf.gii', 'lh.inf.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/HCPA1/lh.inflated.32k_fs_LR.surf.gii in HCPA1
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/HCPA1/lh.inflated.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/HCPA1/lh.inflated.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for HCPA1
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/HCPA1/lh.inf.32k_fs_LR.surf.gii in HCPA1
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/HCPA1/lh.inf.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/HCPA1/lh.inf.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for HCPA1
# pial.*\.32k_fs_LR\.surf\.gii
# ['lh.pial.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I48/lh.pial.32k_fs_LR.surf.gii in I48
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I48/lh.pial.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I48/lh.pial.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I48
# white.*\.32k_fs_LR\.surf\.gii
# ['lh.white.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I48/lh.white.32k_fs_LR.surf.gii in I48
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I48/lh.white.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I48/lh.white.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I48
# inf.*\.32k_fs_LR\.surf\.gii
# ['lh.inflated.32k_fs_LR.surf.gii', 'lh.inf.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I48/lh.inflated.32k_fs_LR.surf.gii in I48
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I48/lh.inflated.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I48/lh.inflated.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I48
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I48/lh.inf.32k_fs_LR.surf.gii in I48
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I48/lh.inf.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I48/lh.inf.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I48
# pial.*\.32k_fs_LR\.surf\.gii
# ['lh.pial.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I46/lh.pial.32k_fs_LR.surf.gii in I46
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I46/lh.pial.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I46/lh.pial.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I46
# white.*\.32k_fs_LR\.surf\.gii
# ['lh.white.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I46/lh.white.32k_fs_LR.surf.gii in I46
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I46/lh.white.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I46/lh.white.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I46
# inf.*\.32k_fs_LR\.surf\.gii
# ['lh.inflated.32k_fs_LR.surf.gii', 'lh.inf.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I46/lh.inflated.32k_fs_LR.surf.gii in I46
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I46/lh.inflated.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I46/lh.inflated.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I46
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I46/lh.inf.32k_fs_LR.surf.gii in I46
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I46/lh.inf.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I46/lh.inf.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I46
# pial.*\.32k_fs_LR\.surf\.gii
# ['rh.pial.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I60/rh.pial.32k_fs_LR.surf.gii in I60
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I60/rh.pial.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I60/rh.pial.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I60
# white.*\.32k_fs_LR\.surf\.gii
# ['rh.white.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I60/rh.white.32k_fs_LR.surf.gii in I60
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I60/rh.white.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I60/rh.white.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I60
# inf.*\.32k_fs_LR\.surf\.gii
# ['rh.inflated.32k_fs_LR.surf.gii', 'rh.inf.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I60/rh.inflated.32k_fs_LR.surf.gii in I60
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I60/rh.inflated.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I60/rh.inflated.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I60
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I60/rh.inf.32k_fs_LR.surf.gii in I60
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I60/rh.inf.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I60/rh.inf.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I60
# pial.*\.32k_fs_LR\.surf\.gii
# ['lh.pial.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I58/lh.pial.32k_fs_LR.surf.gii in I58
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I58/lh.pial.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I58/lh.pial.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I58
# white.*\.32k_fs_LR\.surf\.gii
# ['lh.white.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I58/lh.white.32k_fs_LR.surf.gii in I58
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I58/lh.white.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I58/lh.white.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I58
# inf.*\.32k_fs_LR\.surf\.gii
# ['lh.inflated.32k_fs_LR.surf.gii', 'lh.inf.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I58/lh.inflated.32k_fs_LR.surf.gii in I58
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I58/lh.inflated.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I58/lh.inflated.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I58
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I58/lh.inf.32k_fs_LR.surf.gii in I58
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I58/lh.inf.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I58/lh.inf.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I58
# pial.*\.32k_fs_LR\.surf\.gii
# ['lh.pial.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I57/lh.pial.32k_fs_LR.surf.gii in I57
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I57/lh.pial.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I57/lh.pial.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I57
# white.*\.32k_fs_LR\.surf\.gii
# ['lh.white.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I57/lh.white.32k_fs_LR.surf.gii in I57
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I57/lh.white.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I57/lh.white.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I57
# inf.*\.32k_fs_LR\.surf\.gii
# ['lh.inflated.32k_fs_LR.surf.gii', 'lh.inf.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I57/lh.inflated.32k_fs_LR.surf.gii in I57
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I57/lh.inflated.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I57/lh.inflated.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I57
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I57/lh.inf.32k_fs_LR.surf.gii in I57
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I57/lh.inf.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I57/lh.inf.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I57
# pial.*\.32k_fs_LR\.surf\.gii
# ['rh.pial.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I59/rh.pial.32k_fs_LR.surf.gii in I59
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I59/rh.pial.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I59/rh.pial.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I59
# white.*\.32k_fs_LR\.surf\.gii
# ['rh.white.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I59/rh.white.32k_fs_LR.surf.gii in I59
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I59/rh.white.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I59/rh.white.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I59
# inf.*\.32k_fs_LR\.surf\.gii
# ['rh.inflated.32k_fs_LR.surf.gii', 'rh.inf.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I59/rh.inflated.32k_fs_LR.surf.gii in I59
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I59/rh.inflated.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I59/rh.inflated.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I59
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I59/rh.inf.32k_fs_LR.surf.gii in I59
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I59/rh.inf.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I59/rh.inf.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I59
# pial.*\.32k_fs_LR\.surf\.gii
# ['rh.pial.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I61/rh.pial.32k_fs_LR.surf.gii in I61
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I61/rh.pial.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I61/rh.pial.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I61
# white.*\.32k_fs_LR\.surf\.gii
# ['rh.white.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I61/rh.white.32k_fs_LR.surf.gii in I61
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I61/rh.white.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I61/rh.white.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I61
# inf.*\.32k_fs_LR\.surf\.gii
# ['rh.inflated.32k_fs_LR.surf.gii', 'rh.inf.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I61/rh.inflated.32k_fs_LR.surf.gii in I61
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I61/rh.inflated.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I61/rh.inflated.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I61
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I61/rh.inf.32k_fs_LR.surf.gii in I61
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I61/rh.inf.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I61/rh.inf.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I61
# pial.*\.32k_fs_LR\.surf\.gii
# ['lh.pial.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I45/lh.pial.32k_fs_LR.surf.gii in I45
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I45/lh.pial.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I45/lh.pial.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I45
# white.*\.32k_fs_LR\.surf\.gii
# ['lh.white.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I45/lh.white.32k_fs_LR.surf.gii in I45
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I45/lh.white.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I45/lh.white.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I45
# inf.*\.32k_fs_LR\.surf\.gii
# ['lh.inflated.32k_fs_LR.surf.gii', 'lh.inf.32k_fs_LR.surf.gii']
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I45/lh.inflated.32k_fs_LR.surf.gii in I45
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I45/lh.inflated.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I45/lh.inflated.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I45
# Found /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I45/lh.inf.32k_fs_LR.surf.gii in I45
# Surface normal output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I45/lh.inf.32k_fs_LR.surfnorm.func.gii
# Coordinate output file: /Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data//exvivo2/I45/lh.inf.32k_fs_LR.coord.func.gii
# Successfully calculated surface normals and coordinates for I45

# %% [markdown]
# ### Calculate surface with X spacing along the surface normals

# %%
#method 0: half voxel up and down (if spacing_mm is 0.12mm, then 0.06mm up and down)
#method 1: full voxel length along the surface normal (if spacing_mm is 0.12mm, then 0.12mm up and down)
#090925 DJ - Ting suggested to keep the spacing_mm as 0.24mm or 0.12mm and maximum steps at 8 or 16, respectively

#params = {'spacing_mm': 0.24, 'dist_max_mm': 0.96, 'method':0}
params = {'spacing_mm': 0.24, 'dist_max_mm': 0.96, 'method':1}
#get all the folders (subjects) in the current directory
#path = "/Users/dennis.jungchildmind.org/Desktop/exvivo"
#save_path = "/Users/dennis.jungchildmind.org/Desktop/exvivo_voxel_up_and_down"
path = "/Users/dennis.jungchildmind.org/Desktop/To-be-uploaded-to-CMI-server/data/thickness_data/exvivo2"
save_path = "/Users/dennis.jungchildmind.org/Desktop/exvivo2_voxel_up_and_down"

subject_folders = [f for f in os.listdir(path) if os.path.isdir(os.path.join(path, f))]


def get_surface_xyz(path_surf_norm, path_surf_coords, spacing_mm=0.12, dist_max_mm=2):
    """Generate and plot intensity differences at varying distances from cortical surface"""
    
    # Load surface data
    surf_norm = nib.load(path_surf_norm)
    surf_coords = nib.load(path_surf_coords)
    
    # Extract coordinates and normals
    norm_xyz = np.array([surf_norm.darrays[i].data for i in range(3)])
    surf_xyz = np.array([surf_coords.darrays[i].data for i in range(3)])

    #method 1 
    if params['method'] == 0:
        #calculate half voxel up (spacing mm/2) and down (spacing mm/2) from the surface along the surfarce normal 
        dist_array = np.flipud(np.concatenate([-np.arange(spacing_mm/2, dist_max_mm, spacing_mm)[::-1], np.arange(spacing_mm/2, dist_max_mm, spacing_mm)]))
    elif params['method'] == 1:
        #calculate full voxel length along the surface normal
        dist_array = np.flipud(np.concatenate([-np.arange(spacing_mm, dist_max_mm + spacing_mm, spacing_mm)[::-1], [0], 
                                        np.arange(spacing_mm, dist_max_mm + spacing_mm, spacing_mm)]))
    
    #calcualte the voxel coordinates up along the surface normal
    all_points = [surf_xyz.T + norm_xyz.T * d for d in dist_array]
    
    return all_points, dist_array


for subject_name in subject_folders:
    #check if there is a file that includes  "32k_fs_LR.surf.gii"
    #these files are calculated using the "calculate_surface_normal_and_coordinates.py" script
    #or you can just calculate them using workbench command*
    for layers in ["inf"]:
        regex_target_1 = f"{layers}.32k_fs_LR.surfnorm.func.gii"
        regex_target_2 = f"{layers}.32k_fs_LR.coord.func.gii"

        files = os.listdir(os.path.join(path, subject_name))
        matching_surfnorm = [f for f in files if regex_target_1 in f]
        matching_coord = [f for f in files if regex_target_2 in f]
        print(matching_surfnorm)
        print(matching_coord)
        
        if matching_surfnorm and matching_coord:
            for i,file in enumerate(matching_surfnorm):
                surfacenorm_file = os.path.join(path, subject_name, matching_surfnorm[i])
                coord_file = os.path.join(path, subject_name, matching_coord[i])

                #get the hemisphere from the file name
                all_points, dist_array = get_surface_xyz(
                    surfacenorm_file,
                    coord_file,
                    spacing_mm=params['spacing_mm'],
                    dist_max_mm=params['dist_max_mm']
                )
               
                hemi = matching_surfnorm[0].split('.')[0].split('_')[-1]
                #subject_name = 'I48_new_confidence'
                tmp = nib.load(os.path.join(path, subject_name, f'{hemi}.inf.32k_fs_LR.surf.gii'))

                # Create output directory once
                output_dir = os.path.join(save_path, subject_name, f'surf_voxel_up_and_down', f'{int(params["spacing_mm"]*1000)}um_method{params["method"]}')
                os.makedirs(output_dir, exist_ok=True)

                for j in range(len(all_points)):
                    # Force assignment using setfield
                    new_data = np.array(all_points[j], dtype=tmp.darrays[0].data.dtype)
                    tmp.darrays[0].__dict__['data'] = new_data

                    output_file = os.path.join(output_dir, f'{hemi}.inf.32k_fs_LR_{dist_array[j]:.2f}.surf.gii')
                    nib.save(tmp, output_file)
